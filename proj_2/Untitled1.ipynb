# %%
# Import Libraries
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import time
# A class that models the Neural Net with L-layers and
# N neurons in each layer. It also contains the functions
# for training, testing, and optimizing the Neural Network

np.random.seed(100)

class DeepNN:

    # Constructor to build the structure of the Neural Network
    # It accepts the layers in the format of [2,3,1] -> 2 Neuron Input Layer,
    # 3 Neuron Hidden Layer and 1 Neuron output layer
    def __init__(self, layers, activations, epsilon = 0.55):
        ############################### Initialize the number of layers and neurons
        self.layers = layers
        self.num_layers = len(layers)
        self.hidden_layers = len(layers) - 2
        self.input_neurons = layers[0]
        self.output_neurons = layers[-1]

        ########## Intialize parameters for Forward Propogation
        # Initialize Weights
        self.epsilon = epsilon  # Random Weight Initialization Factor
        self.weights = []
        for i in range(self.num_layers-2):
            self.weights.append(np.random.randn(layers[i]+1, layers[i+1]+1)*2*self.epsilon - self.epsilon)
                        # We add a +1 to incorporate for weights from the +1 neuron for the bias
        self.weights.append(np.random.randn(layers[-2]+1, layers[-1])*2*self.epsilon - self.epsilon)

        self.a = [] # To keep track of activations
        self.z = [] # To keep track of layer values
        self.activations = activations # Activations for each layer

        ######### Intialize parameters for Backward Propogation
        self.delta = []
        self.gradient = []

        # Initialize Scaling
        self.scaler = preprocessing.StandardScaler()

    ################################### Define Some Activation Functions and their derivatives ##################
    def sigmoid(self,x):
        return 1.0/(1.0 + np.exp(-x))

    def sigmoidPrime(self,x):
        return self.sigmoid(x)*(1-self.sigmoid(x))

    def reLU(self,x):
        return np.maximum(x, 0)

    def reLUPrime(self,x):
        return np.where(x > 0, 1.0, 0.0)

    def softmax(self,x):
        return np.exp(x)/np.sum(np.exp(x), axis = 0)

    def tanh(self,x):
        return np.tanh(x)

    def tanh_prime(self,x):
        return 1 - np.power(np.tanh(x),2)

    def identity(self,x):
        return x

    def identity_prime(self,x):
        return 1

    ######################################### Cost Functions #############################################
    # Least Squares
    def least_squares_cost(self,t):
        return 0.5*np.mean( (t-self.a[-1])**2 )

    # Cross Entropy Log Loss Function
    def log_loss(self,t):
        return np.mean( np.nan_to_num( -1*t*np.log(self.a[-1]) - (1-t)*np.log(1-self.a[-1]) ) )

    ######################################### Forward Feed ##############################################
    def forwardFeed(self, X):
        a = [X] # Keep Track of activations
        z = []

        # Add Bias
        c = np.ones([1,a[0].shape[0]]).reshape(a[0].shape[0],1)
        a[0] = np.concatenate((c,a[0]), axis=1)
#         print(a)
        for i in range(self.num_layers-1):
#             print(a[i])
            z.append(np.dot(a[i],self.weights[i]))
            if(self.activations[i] == 'sigmoid'):
                a.append(self.sigmoid(z[i]))
            elif(self.activations[i] == 'reLU'):
                a.append(self.reLU(z[i]))
            elif(self.activations[i] == 'tanh'):
                a.append(self.tanh(z[i]))
            elif(self.activations[i] == 'softmax'):
                a.append(self.softmax(z[i]))
            elif(self.activations[i] == 'identity'):
                a.append(self.identity(z[i]))
        self.a = a
        self.z = z

    def backPropogate(self,y):

        delta = []
        gradient = []
        weights_flipped = self.weights[::-1]
        z_flipped = self.z[::-1]
        activations_flipped = self.a[::-1]
        activation_func_flipped = self.activations[::-1]
        delta.append(activations_flipped[0] - y)
        for i in range(0,self.num_layers-2):
                if(activation_func_flipped[i] == 'sigmoid'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.sigmoidPrime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'reLU'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.reLUPrime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'tanh'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.tanh_prime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'identity'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T ) * self.identity_prime(z_flipped[i+1]) )
                elif(activation_func_flipped[i] == 'softmax'):
                    delta.append( np.dot(delta[i], weights_flipped[i].T))

        delta = delta[::-1]

        for i in range(len(delta)):
            gradient.append( np.dot(self.a[i].T, delta[i]) )
            
        self.delta = delta
        self.gradient = gradient

    def learn(self, epochs, learning_rate, X, y, cost_func, metrics_at=10, optimizer = '', batch_size=10, scaler_type='standard_scaler', split=False, test_size=0.25, beta = 0.9, beta_2 = 0.99, epsilon=10e-8):
        start = time.time()
        
        cost=[]
        
        v_n = []
        s_n = []
        for j in range(len(self.weights)):
            v_n.append(np.zeros(self.weights[j].shape))
            s_n.append(np.zeros(self.weights[j].shape))
            
        if scaler_type == 'min_max_scaler':
            self.scaler = preprocessing.MinMaxScaler()
        X = self.scaler.fit_transform(X)

        if split:
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)
            X = X_train
            y = y_train

        
        for i in range(epochs):
                if optimizer == 'mini_batch':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            v_n[j] = beta * v_n[j] + (1-beta) * self.gradient[j]
                            self.weights[j] = self.weights[j] - learning_rate * v_n[j]
                elif optimizer == 'rmsprop':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                            
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            s_n[j] = beta_2 * s_n[j] + (1-beta_2) * np.power(self.gradient[j],2)
                            self.weights[j] = self.weights[j] - learning_rate * self.gradient[j]/np.sqrt(s_n[j]+epsilon)
                elif optimizer == 'adam':
                    # Batch size of 1 makes it SGD
                    no_of_batches = int(len(X)/batch_size)
                    for k in range(no_of_batches):
                        if k==no_of_batches-1:
                            X_sgd = X[k*batch_size:]
                            y_sgd = y[k*batch_size:]
                        else:
                            X_sgd = X[k*batch_size:(k+1)*batch_size]
                            y_sgd = y[k*batch_size:(k+1)*batch_size]
                        self.forwardFeed(X_sgd)
                        self.backPropogate(y_sgd)
                        for j in range(len(self.gradient)):
                            v_n[j] = beta * v_n[j] + (1-beta) * self.gradient[j]
                            s_n[j] = beta_2 * s_n[j] + (1-beta_2) * np.power(self.gradient[j],2)
                            
                            # Beta Correction
                            v_n[j] = v_n[j] / (1-np.power(beta,k)+epsilon)
                            s_n[j] = s_n[j] / (1-np.power(beta_2,k)+epsilon)
                            
                            self.weights[j] = self.weights[j] - learning_rate * v_n[j]/np.sqrt(s_n[j]+epsilon)

                else:
                    self.forwardFeed(X)
                    self.backPropogate(y)
                    for j in range(len(self.gradient)):
                        self.weights[j] = self.weights[j] - learning_rate * self.gradient[j]

                if(i%metrics_at == 0):
                    self.forwardFeed(X)
                    print('Effective epoch: ', i/metrics_at + 1)
                    if(cost_func == 'log_loss'):
                        cost.append(self.log_loss(y))
                        print('Accuracy: ', np.mean(np.round(self.think(X))==y) * 100, '%')
                    elif(cost_func == 'least_squares'):
                        cost.append(self.least_squares_cost(y))
                    print('Cost: ', cost[-1], '\n')

        

        end = time.time()
        
        
        if(cost_func == 'log_loss' and split):
            print('Testing Accuracy: ', np.mean(np.round(self.think(X_test))==y_test) * 100, '%')
        plt.plot(cost)
        print('Time Taken: ', end-start, ' seconds')
        return self.weights

    def think(self,X, scale=True):
        if scale:
            X = self.scaler.fit_transform(X)
        a = [X] # Keep Track of activations
        z = []

        # Add Bias
        c = np.ones([1,a[0].shape[0]]).reshape(a[0].shape[0],1)
        a[0] = np.concatenate((c,a[0]), axis=1)
#         print(a)
        for i in range(self.num_layers-1):
#             print(a[i])
            z.append(np.dot(a[i],self.weights[i]))
            if(self.activations[i] == 'sigmoid'):
                a.append(self.sigmoid(z[i]))
            elif(self.activations[i] == 'reLU'):
                a.append(self.reLU(z[i]))
            elif(self.activations[i] == 'tanh'):
                a.append(self.tanh(z[i]))
            elif(self.activations[i] == 'softmax'):
                a.append(self.softmax(z[i]))
            elif(self.activations[i] == 'identity'):
                a.append(self.identity(z[i]))
                
        return a[-1]


# In[83]:


########################## Part a) - Generate Dataset
X = np.array([[-1, -1],[1, 1],[-1, 1],[1, -1]],dtype='float')
t = np.array([1, 1, 0, 0],dtype='float').reshape(4,1)


NN = DeepNN([2,2,1], activations=['tanh','sigmoid'], epsilon = 0.12)

w = NN.learn(epochs=1500, learning_rate=0.1, X=X, y=t, cost_func='log_loss', metrics_at=1, split=False)
plt.title('XOR Cost Function')
print('Accuracy: ',np.mean(np.round(NN.think(X))==t) * 100)


x_mesh = np.linspace(-1.2,1.2,30).reshape(30,1)
y_mesh = np.linspace(-1.2,1.2,30).reshape(30,1)

X_mesh, Y_mesh = np.meshgrid(x_mesh,x_mesh)
X_test = np.hstack((x_mesh,y_mesh))



# Classify Points for Decision Boundary
predicitions = np.zeros([len(x_mesh),len(y_mesh)])
for i in range(len(X_mesh)):
    for j in range(len(Y_mesh)):
        pnt = np.array([X_mesh[i,j],Y_mesh[i,j]]).reshape(1,2)
        predicitions[i,j] = NN.think(pnt, scale=False)[0,0]



import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X_mesh, Y_mesh, predicitions-0.5,1000)

x_xor = [-1, 1, -1, 1]
y_xor = [-1, 1, 1, -1]
t_xor = [0.5, 0.5, -0.5, -0.5]
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.scatter(x_xor, y_xor, t_xor, c='r')
plt.title('XOR Decision Surface using Logistic Sigmoid')


# Part - b Generate Dataset
plt.figure()
np.random.seed(100)
X = np.sort(2*np.random.rand(50,1)-1)
t = np.sin(2*(np.pi)*X) + 0.3*np.random.randn(50,1)

# Part - b Regression
np.random.seed(100)
X = np.sort(2*np.random.rand(50,1)-1)
t = np.sin(2*(np.pi)*X) + 0.3*np.random.randn(50,1)


# Build NN with 20 hidden units
NN2 = DeepNN([1,2,1], activations=['tanh','identity'],epsilon=0.9)
w = NN2.learn(epochs=50000, learning_rate=0.001, X=X, y=t, cost_func='least_squares', metrics_at=10000, optimizer='rmsprop',batch_size=50)
plt.title('Regression with 20 Hidden Units Cost Function')

# plot the model
x_mesh = np.linspace(np.min(X),np.max(X),500).reshape(500,1)
y = NN2.think(x_mesh)


plt.figure()
plt.plot(x_mesh,y,'r')
plt.scatter(X,t)
plt.title('Regression with 20 hidden Units')

# Build NN with 20 hidden units
plt.figure()
NN2 = DeepNN([1,20,1], activations=['tanh','identity'],epsilon=2.1)
w = NN2.learn(epochs=10000, learning_rate=0.001, X=X, y=t, cost_func='least_squares', metrics_at=1000, optimizer='rmsprop',batch_size=5)
plt.title('Regression with 20 Hidden Units Cost Function')

# plot the model
x_mesh = np.linspace(np.min(X)-0.25,np.max(X)+0.25,500).reshape(500,1)
y = NN2.think(x_mesh)

plt.figure()
plt.plot(x_mesh, y, 'r')
plt.scatter(X,t)
plt.title('Regression with 20 hidden Units')
# Out:
# Effective epoch:  1.0
# Accuracy:  50.0 %
# Cost:  0.6941556263320445
#
# Effective epoch:  2.0
# Accuracy:  50.0 %
# Cost:  0.6941017873121202
#
# Effective epoch:  3.0
# Accuracy:  50.0 %
# Cost:  0.694050472536804
#
# Effective epoch:  4.0
# Accuracy:  50.0 %
# Cost:  0.6940015389993538
#
# Effective epoch:  5.0
# Accuracy:  50.0 %
# Cost:  0.6939548529449654
#
# Effective epoch:  6.0
# Accuracy:  50.0 %
# Cost:  0.6939102891878639
#
# Effective epoch:  7.0
# Accuracy:  50.0 %
# Cost:  0.6938677304851791
#
# Effective epoch:  8.0
# Accuracy:  50.0 %
# Cost:  0.6938270669623342
#
# Effective epoch:  9.0
# Accuracy:  50.0 %
# Cost:  0.6937881955852201
#
# Effective epoch:  10.0
# Accuracy:  50.0 %
# Cost:  0.6937510196749088
#
# Effective epoch:  11.0
# Accuracy:  50.0 %
# Cost:  0.6937154484610818
#
# Effective epoch:  12.0
# Accuracy:  50.0 %
# Cost:  0.6936813966707333
#
# Effective epoch:  13.0
# Accuracy:  50.0 %
# Cost:  0.6936487841490409
#
# Effective epoch:  14.0
# Accuracy:  50.0 %
# Cost:  0.6936175355096055
#
# Effective epoch:  15.0
# Accuracy:  50.0 %
# Cost:  0.6935875798115234
#
# Effective epoch:  16.0
# Accuracy:  50.0 %
# Cost:  0.6935588502610015
#
# Effective epoch:  17.0
# Accuracy:  50.0 %
# Cost:  0.6935312839354393
#
# Effective epoch:  18.0
# Accuracy:  50.0 %
# Cost:  0.6935048215280976
#
# Effective epoch:  19.0
# Accuracy:  50.0 %
# Cost:  0.6934794071116422
#
# Effective epoch:  20.0
# Accuracy:  50.0 %
# Cost:  0.6934549879190173
#
# Effective epoch:  21.0
# Accuracy:  50.0 %
# Cost:  0.6934315141402313
#
# Effective epoch:  22.0
# Accuracy:  50.0 %
# Cost:  0.6934089387337765
#
# Effective epoch:  23.0
# Accuracy:  50.0 %
# Cost:  0.6933872172515083
#
# Effective epoch:  24.0
# Accuracy:  50.0 %
# Cost:  0.6933663076759213
#
# Effective epoch:  25.0
# Accuracy:  50.0 %
# Cost:  0.693346170268846
#
# Effective epoch:  26.0
# Accuracy:  50.0 %
# Cost:  0.6933267674306766
#
# Effective epoch:  27.0
# Accuracy:  50.0 %
# Cost:  0.6933080635693185
#
# Effective epoch:  28.0
# Accuracy:  50.0 %
# Cost:  0.6932900249781115
#
# Effective epoch:  29.0
# Accuracy:  50.0 %
# Cost:  0.693272619722045
#
# Effective epoch:  30.0
# Accuracy:  50.0 %
# Cost:  0.6932558175316429
#
# Effective epoch:  31.0
# Accuracy:  50.0 %
# Cost:  0.6932395897039457
#
# Effective epoch:  32.0
# Accuracy:  50.0 %
# Cost:  0.6932239090100631
#
# Effective epoch:  33.0
# Accuracy:  50.0 %
# Cost:  0.6932087496088128
#
# Effective epoch:  34.0
# Accuracy:  50.0 %
# Cost:  0.6931940869660066
#
# Effective epoch:  35.0
# Accuracy:  50.0 %
# Cost:  0.6931798977789678
#
# Effective epoch:  36.0
# Accuracy:  50.0 %
# Cost:  0.6931661599059125
#
# Effective epoch:  37.0
# Accuracy:  50.0 %
# Cost:  0.6931528522998417
#
# Effective epoch:  38.0
# Accuracy:  50.0 %
# Cost:  0.693139954946627
#
# Effective epoch:  39.0
# Accuracy:  50.0 %
# Cost:  0.693127448806998
#
# Effective epoch:  40.0
# Accuracy:  50.0 %
# Cost:  0.693115315762157
#
# Effective epoch:  41.0
# Accuracy:  50.0 %
# Cost:  0.6931035385627686
#
# Effective epoch:  42.0
# Accuracy:  50.0 %
# Cost:  0.693092100781097
#
# Effective epoch:  43.0
# Accuracy:  50.0 %
# Cost:  0.6930809867660709
#
# Effective epoch:  44.0
# Accuracy:  50.0 %
# Cost:  0.6930701816010825
#
# Effective epoch:  45.0
# Accuracy:  50.0 %
# Cost:  0.6930596710643323
#
# Effective epoch:  46.0
# Accuracy:  50.0 %
# Cost:  0.6930494415915537
#
# Effective epoch:  47.0
# Accuracy:  50.0 %
# Cost:  0.6930394802409557
#
# Effective epoch:  48.0
# Accuracy:  50.0 %
# Cost:  0.6930297746602403
#
# Effective epoch:  49.0
# Accuracy:  50.0 %
# Cost:  0.6930203130555576
#
# Effective epoch:  50.0
# Accuracy:  50.0 %
# Cost:  0.6930110841622719
#
# Effective epoch:  51.0
# Accuracy:  50.0 %
# Cost:  0.6930020772174232
#
# Effective epoch:  52.0
# Accuracy:  50.0 %
# Cost:  0.6929932819337743
#
# Effective epoch:  53.0
# Accuracy:  50.0 %
# Cost:  0.6929846884753426
#
# Effective epoch:  54.0
# Accuracy:  50.0 %
# Cost:  0.6929762874343217
#
# Effective epoch:  55.0
# Accuracy:  50.0 %
# Cost:  0.6929680698093068
#
# Effective epoch:  56.0
# Accuracy:  50.0 %
# Cost:  0.6929600269847411
#
# Effective epoch:  57.0
# Accuracy:  50.0 %
# Cost:  0.6929521507115073
#
# Effective epoch:  58.0
# Accuracy:  50.0 %
# Cost:  0.6929444330885939
#
# Effective epoch:  59.0
# Accuracy:  50.0 %
# Cost:  0.6929368665457697
#
# Effective epoch:  60.0
# Accuracy:  50.0 %
# Cost:  0.692929443827205
#
# Effective epoch:  61.0
# Accuracy:  50.0 %
# Cost:  0.6929221579759831
#
# Effective epoch:  62.0
# Accuracy:  25.0 %
# Cost:  0.6929150023194459
#
# Effective epoch:  63.0
# Accuracy:  25.0 %
# Cost:  0.692907970455326
#
# Effective epoch:  64.0
# Accuracy:  25.0 %
# Cost:  0.6929010562386178
#
# Effective epoch:  65.0
# Accuracy:  25.0 %
# Cost:  0.692894253769142
#
# Effective epoch:  66.0
# Accuracy:  25.0 %
# Cost:  0.6928875573797657
#
# Effective epoch:  67.0
# Accuracy:  25.0 %
# Cost:  0.6928809616252363
#
# Effective epoch:  68.0
# Accuracy:  25.0 %
# Cost:  0.6928744612715961
#
# Effective epoch:  69.0
# Accuracy:  25.0 %
# Cost:  0.6928680512861437
#
# Effective epoch:  70.0
# Accuracy:  25.0 %
# Cost:  0.6928617268279073
#
# Effective epoch:  71.0
# Accuracy:  25.0 %
# Cost:  0.692855483238606
#
# Effective epoch:  72.0
# Accuracy:  25.0 %
# Cost:  0.6928493160340667
#
# Effective epoch:  73.0
# Accuracy:  25.0 %
# Cost:  0.6928432208960738
#
# Effective epoch:  74.0
# Accuracy:  25.0 %
# Cost:  0.6928371936646235
#
# Effective epoch:  75.0
# Accuracy:  25.0 %
# Cost:  0.6928312303305669
#
# Effective epoch:  76.0
# Accuracy:  25.0 %
# Cost:  0.6928253270286114
#
# Effective epoch:  77.0
# Accuracy:  25.0 %
# Cost:  0.6928194800306676
#
# Effective epoch:  78.0
# Accuracy:  25.0 %
# Cost:  0.6928136857395186
#
# Effective epoch:  79.0
# Accuracy:  25.0 %
# Cost:  0.6928079406827982
#
# Effective epoch:  80.0
# Accuracy:  25.0 %
# Cost:  0.6928022415072536
#
# Effective epoch:  81.0
# Accuracy:  25.0 %
# Cost:  0.6927965849732864
#
# Effective epoch:  82.0
# Accuracy:  25.0 %
# Cost:  0.6927909679497506
#
# Effective epoch:  83.0
# Accuracy:  25.0 %
# Cost:  0.6927853874089946
#
# Effective epoch:  84.0
# Accuracy:  25.0 %
# Cost:  0.6927798404221374
#
# Effective epoch:  85.0
# Accuracy:  25.0 %
# Cost:  0.6927743241545617
#
# Effective epoch:  86.0
# Accuracy:  25.0 %
# Cost:  0.6927688358616172
#
# Effective epoch:  87.0
# Accuracy:  25.0 %
# Cost:  0.6927633728845192
#
# Effective epoch:  88.0
# Accuracy:  25.0 %
# Cost:  0.6927579326464355
#
# Effective epoch:  89.0
# Accuracy:  25.0 %
# Cost:  0.6927525126487477
#
# Effective epoch:  90.0
# Accuracy:  25.0 %
# Cost:  0.6927471104674827
#
# Effective epoch:  91.0
# Accuracy:  25.0 %
# Cost:  0.6927417237499016
#
# Effective epoch:  92.0
# Accuracy:  25.0 %
# Cost:  0.6927363502112405
#
# Effective epoch:  93.0
# Accuracy:  25.0 %
# Cost:  0.6927309876315932
#
# Effective epoch:  94.0
# Accuracy:  25.0 %
# Cost:  0.6927256338529313
#
# Effective epoch:  95.0
# Accuracy:  25.0 %
# Cost:  0.6927202867762509
#
# Effective epoch:  96.0
# Accuracy:  25.0 %
# Cost:  0.692714944358845
#
# Effective epoch:  97.0
# Accuracy:  25.0 %
# Cost:  0.6927096046116884
#
# Effective epoch:  98.0
# Accuracy:  25.0 %
# Cost:  0.6927042655969358
#
# Effective epoch:  99.0
# Accuracy:  25.0 %
# Cost:  0.6926989254255231
#
# Effective epoch:  100.0
# Accuracy:  25.0 %
# Cost:  0.6926935822548699
#
# Effective epoch:  101.0
# Accuracy:  25.0 %
# Cost:  0.692688234286675
#
# Effective epoch:  102.0
# Accuracy:  25.0 %
# Cost:  0.6926828797648031
#
# Effective epoch:  103.0
# Accuracy:  25.0 %
# Cost:  0.6926775169732569
#
# Effective epoch:  104.0
# Accuracy:  25.0 %
# Cost:  0.6926721442342294
#
# Effective epoch:  105.0
# Accuracy:  25.0 %
# Cost:  0.6926667599062365
#
# Effective epoch:  106.0
# Accuracy:  25.0 %
# Cost:  0.6926613623823199
#
# Effective epoch:  107.0
# Accuracy:  25.0 %
# Cost:  0.6926559500883219
#
# Effective epoch:  108.0
# Accuracy:  25.0 %
# Cost:  0.6926505214812262
#
# Effective epoch:  109.0
# Accuracy:  25.0 %
# Cost:  0.6926450750475637
#
# Effective epoch:  110.0
# Accuracy:  25.0 %
# Cost:  0.6926396093018756
#
# Effective epoch:  111.0
# Accuracy:  25.0 %
# Cost:  0.6926341227852368
#
# Effective epoch:  112.0
# Accuracy:  25.0 %
# Cost:  0.6926286140638329
#
# Effective epoch:  113.0
# Accuracy:  25.0 %
# Cost:  0.6926230817275888
#
# Effective epoch:  114.0
# Accuracy:  25.0 %
# Cost:  0.6926175243888477
#
# Effective epoch:  115.0
# Accuracy:  25.0 %
# Cost:  0.6926119406810967
#
# Effective epoch:  116.0
# Accuracy:  25.0 %
# Cost:  0.692606329257738
#
# Effective epoch:  117.0
# Accuracy:  25.0 %
# Cost:  0.6926006887909022
#
# Effective epoch:  118.0
# Accuracy:  25.0 %
# Cost:  0.6925950179703023
#
# Effective epoch:  119.0
# Accuracy:  25.0 %
# Cost:  0.6925893155021273
#
# Effective epoch:  120.0
# Accuracy:  25.0 %
# Cost:  0.6925835801079718
#
# Effective epoch:  121.0
# Accuracy:  25.0 %
# Cost:  0.692577810523802
#
# Effective epoch:  122.0
# Accuracy:  25.0 %
# Cost:  0.692572005498953
#
# Effective epoch:  123.0
# Accuracy:  25.0 %
# Cost:  0.6925661637951601
#
# Effective epoch:  124.0
# Accuracy:  25.0 %
# Cost:  0.6925602841856202
#
# Effective epoch:  125.0
# Accuracy:  25.0 %
# Cost:  0.6925543654540802
#
# Effective epoch:  126.0
# Accuracy:  25.0 %
# Cost:  0.6925484063939555
#
# Effective epoch:  127.0
# Accuracy:  25.0 %
# Cost:  0.6925424058074724
#
# Effective epoch:  128.0
# Accuracy:  25.0 %
# Cost:  0.6925363625048364
#
# Effective epoch:  129.0
# Accuracy:  25.0 %
# Cost:  0.6925302753034248
#
# Effective epoch:  130.0
# Accuracy:  25.0 %
# Cost:  0.692524143027
#
# Effective epoch:  131.0
# Accuracy:  25.0 %
# Cost:  0.6925179645049454
#
# Effective epoch:  132.0
# Accuracy:  25.0 %
# Cost:  0.6925117385715213
#
# Effective epoch:  133.0
# Accuracy:  25.0 %
# Cost:  0.6925054640651409
#
# Effective epoch:  134.0
# Accuracy:  25.0 %
# Cost:  0.6924991398276625
#
# Effective epoch:  135.0
# Accuracy:  25.0 %
# Cost:  0.6924927647037008
#
# Effective epoch:  136.0
# Accuracy:  25.0 %
# Cost:  0.6924863375399545
#
# Effective epoch:  137.0
# Accuracy:  25.0 %
# Cost:  0.6924798571845491
#
# Effective epoch:  138.0
# Accuracy:  25.0 %
# Cost:  0.6924733224863935
#
# Effective epoch:  139.0
# Accuracy:  25.0 %
# Cost:  0.6924667322945534
#
# Effective epoch:  140.0
# Accuracy:  25.0 %
# Cost:  0.6924600854576336
#
# Effective epoch:  141.0
# Accuracy:  25.0 %
# Cost:  0.6924533808231779
#
# Effective epoch:  142.0
# Accuracy:  25.0 %
# Cost:  0.6924466172370756
#
# Effective epoch:  143.0
# Accuracy:  25.0 %
# Cost:  0.6924397935429835
#
# Effective epoch:  144.0
# Accuracy:  25.0 %
# Cost:  0.6924329085817549
#
# Effective epoch:  145.0
# Accuracy:  25.0 %
# Cost:  0.6924259611908808
#
# Effective epoch:  146.0
# Accuracy:  25.0 %
# Cost:  0.6924189502039391
#
# Effective epoch:  147.0
# Accuracy:  25.0 %
# Cost:  0.692411874450052
#
# Effective epoch:  148.0
# Accuracy:  25.0 %
# Cost:  0.692404732753353
#
# Effective epoch:  149.0
# Accuracy:  25.0 %
# Cost:  0.6923975239324599
#
# Effective epoch:  150.0
# Accuracy:  25.0 %
# Cost:  0.6923902467999555
#
# Effective epoch:  151.0
# Accuracy:  25.0 %
# Cost:  0.6923829001618744
#
# Effective epoch:  152.0
# Accuracy:  25.0 %
# Cost:  0.6923754828171966
#
# Effective epoch:  153.0
# Accuracy:  25.0 %
# Cost:  0.6923679935573444
#
# Effective epoch:  154.0
# Accuracy:  25.0 %
# Cost:  0.6923604311656878
#
# Effective epoch:  155.0
# Accuracy:  25.0 %
# Cost:  0.6923527944170511
#
# Effective epoch:  156.0
# Accuracy:  25.0 %
# Cost:  0.6923450820772253
#
# Effective epoch:  157.0
# Accuracy:  25.0 %
# Cost:  0.6923372929024846
#
# Effective epoch:  158.0
# Accuracy:  25.0 %
# Cost:  0.6923294256391049
#
# Effective epoch:  159.0
# Accuracy:  25.0 %
# Cost:  0.6923214790228862
#
# Effective epoch:  160.0
# Accuracy:  25.0 %
# Cost:  0.6923134517786773
#
# Effective epoch:  161.0
# Accuracy:  25.0 %
# Cost:  0.6923053426199022
#
# Effective epoch:  162.0
# Accuracy:  25.0 %
# Cost:  0.692297150248089
#
# Effective epoch:  163.0
# Accuracy:  25.0 %
# Cost:  0.6922888733524
#
# Effective epoch:  164.0
# Accuracy:  25.0 %
# Cost:  0.6922805106091618
#
# Effective epoch:  165.0
# Accuracy:  25.0 %
# Cost:  0.6922720606813979
#
# Effective epoch:  166.0
# Accuracy:  25.0 %
# Cost:  0.6922635222183611
#
# Effective epoch:  167.0
# Accuracy:  25.0 %
# Cost:  0.6922548938550648
#
# Effective epoch:  168.0
# Accuracy:  25.0 %
# Cost:  0.6922461742118156
#
# Effective epoch:  169.0
# Accuracy:  25.0 %
# Cost:  0.6922373618937436
#
# Effective epoch:  170.0
# Accuracy:  25.0 %
# Cost:  0.6922284554903348
#
# Effective epoch:  171.0
# Accuracy:  25.0 %
# Cost:  0.6922194535749591
#
# Effective epoch:  172.0
# Accuracy:  25.0 %
# Cost:  0.6922103547043974
#
# Effective epoch:  173.0
# Accuracy:  25.0 %
# Cost:  0.6922011574183697
#
# Effective epoch:  174.0
# Accuracy:  25.0 %
# Cost:  0.6921918602390567
#
# Effective epoch:  175.0
# Accuracy:  25.0 %
# Cost:  0.6921824616706231
#
# Effective epoch:  176.0
# Accuracy:  25.0 %
# Cost:  0.6921729601987368
#
# Effective epoch:  177.0
# Accuracy:  25.0 %
# Cost:  0.6921633542900825
#
# Effective epoch:  178.0
# Accuracy:  25.0 %
# Cost:  0.6921536423918768
#
# Effective epoch:  179.0
# Accuracy:  25.0 %
# Cost:  0.6921438229313777
#
# Effective epoch:  180.0
# Accuracy:  25.0 %
# Cost:  0.6921338943153884
#
# Effective epoch:  181.0
# Accuracy:  25.0 %
# Cost:  0.6921238549297606
#
# Effective epoch:  182.0
# Accuracy:  25.0 %
# Cost:  0.6921137031388909
#
# Effective epoch:  183.0
# Accuracy:  25.0 %
# Cost:  0.6921034372852142
#
# Effective epoch:  184.0
# Accuracy:  25.0 %
# Cost:  0.6920930556886913
#
# Effective epoch:  185.0
# Accuracy:  25.0 %
# Cost:  0.6920825566462921
#
# Effective epoch:  186.0
# Accuracy:  25.0 %
# Cost:  0.6920719384314734
#
# Effective epoch:  187.0
# Accuracy:  25.0 %
# Cost:  0.6920611992936508
#
# Effective epoch:  188.0
# Accuracy:  25.0 %
# Cost:  0.6920503374576642
#
# Effective epoch:  189.0
# Accuracy:  25.0 %
# Cost:  0.6920393511232394
#
# Effective epoch:  190.0
# Accuracy:  25.0 %
# Cost:  0.6920282384644412
#
# Effective epoch:  191.0
# Accuracy:  25.0 %
# Cost:  0.6920169976291196
#
# Effective epoch:  192.0
# Accuracy:  25.0 %
# Cost:  0.6920056267383519
#
# Effective epoch:  193.0
# Accuracy:  25.0 %
# Cost:  0.6919941238858747
#
# Effective epoch:  194.0
# Accuracy:  25.0 %
# Cost:  0.6919824871375095
#
# Effective epoch:  195.0
# Accuracy:  25.0 %
# Cost:  0.691970714530582
#
# Effective epoch:  196.0
# Accuracy:  25.0 %
# Cost:  0.6919588040733313
#
# Effective epoch:  197.0
# Accuracy:  25.0 %
# Cost:  0.6919467537443119
#
# Effective epoch:  198.0
# Accuracy:  25.0 %
# Cost:  0.6919345614917884
#
# Effective epoch:  199.0
# Accuracy:  25.0 %
# Cost:  0.6919222252331196
#
# Effective epoch:  200.0
# Accuracy:  25.0 %
# Cost:  0.6919097428541341
#
# Effective epoch:  201.0
# Accuracy:  25.0 %
# Cost:  0.6918971122084981
#
# Effective epoch:  202.0
# Accuracy:  25.0 %
# Cost:  0.691884331117072
#
# Effective epoch:  203.0
# Accuracy:  25.0 %
# Cost:  0.691871397367258
#
# Effective epoch:  204.0
# Accuracy:  25.0 %
# Cost:  0.6918583087123371
#
# Effective epoch:  205.0
# Accuracy:  25.0 %
# Cost:  0.6918450628707972
#
# Effective epoch:  206.0
# Accuracy:  25.0 %
# Cost:  0.6918316575256489
#
# Effective epoch:  207.0
# Accuracy:  25.0 %
# Cost:  0.6918180903237308
#
# Effective epoch:  208.0
# Accuracy:  25.0 %
# Cost:  0.6918043588750048
#
# Effective epoch:  209.0
# Accuracy:  25.0 %
# Cost:  0.6917904607518387
#
# Effective epoch:  210.0
# Accuracy:  25.0 %
# Cost:  0.6917763934882774
#
# Effective epoch:  211.0
# Accuracy:  25.0 %
# Cost:  0.6917621545793023
#
# Effective epoch:  212.0
# Accuracy:  25.0 %
# Cost:  0.6917477414800779
#
# Effective epoch:  213.0
# Accuracy:  25.0 %
# Cost:  0.6917331516051866
#
# Effective epoch:  214.0
# Accuracy:  25.0 %
# Cost:  0.6917183823278493
#
# Effective epoch:  215.0
# Accuracy:  25.0 %
# Cost:  0.6917034309791348
#
# Effective epoch:  216.0
# Accuracy:  25.0 %
# Cost:  0.691688294847152
#
# Effective epoch:  217.0
# Accuracy:  25.0 %
# Cost:  0.691672971176233
#
# Effective epoch:  218.0
# Accuracy:  25.0 %
# Cost:  0.6916574571660989
#
# Effective epoch:  219.0
# Accuracy:  25.0 %
# Cost:  0.6916417499710106
#
# Effective epoch:  220.0
# Accuracy:  25.0 %
# Cost:  0.6916258466989068
#
# Effective epoch:  221.0
# Accuracy:  25.0 %
# Cost:  0.6916097444105264
#
# Effective epoch:  222.0
# Accuracy:  25.0 %
# Cost:  0.691593440118514
#
# Effective epoch:  223.0
# Accuracy:  25.0 %
# Cost:  0.691576930786511
#
# Effective epoch:  224.0
# Accuracy:  25.0 %
# Cost:  0.6915602133282297
#
# Effective epoch:  225.0
# Cost:  0.5902481933371171
#
# Effective epoch:  504.0
# Accuracy:  100.0 %
# Cost:  0.5879685426976928
#
# Effective epoch:  505.0
# Accuracy:  100.0 %
# Cost:  0.5856324824472415
#
# Effective epoch:  506.0
# Accuracy:  100.0 %
# Cost:  0.5832387957966151
#
# Effective epoch:  507.0
# Accuracy:  100.0 %
# Cost:  0.5807862692002257
#
# Effective epoch:  508.0
# Accuracy:  100.0 %
# Cost:  0.5782736955134071
#
# Effective epoch:  509.0
# Accuracy:  100.0 %
# Cost:  0.5756998774094969
#
# Effective epoch:  510.0
# Accuracy:  100.0 %
# Cost:  0.5730636310648649
#
# Effective epoch:  511.0
# Accuracy:  100.0 %
# Cost:  0.5703637901190025
#
# Effective epoch:  512.0
# Accuracy:  100.0 %
# Cost:  0.5675992099154432
#
# Effective epoch:  513.0
# Accuracy:  100.0 %
# Cost:  0.5647687720276904
#
# Effective epoch:  514.0
# Accuracy:  100.0 %
# Cost:  0.561871389072466
#
# Effective epoch:  515.0
# Accuracy:  100.0 %
# Cost:  0.5589060098104438
#
# Effective epoch:  516.0
# Accuracy:  100.0 %
# Cost:  0.5558716245321853
#
# Effective epoch:  517.0
# Accuracy:  100.0 %
# Cost:  0.5527672707242417
#
# Effective epoch:  518.0
# Accuracy:  100.0 %
# Cost:  0.5495920390073046
#
# Effective epoch:  519.0
# Accuracy:  100.0 %
# Cost:  0.5463450793349094
#
# Effective epoch:  520.0
# Accuracy:  100.0 %
# Cost:  0.5430256074374711
#
# Effective epoch:  521.0
# Accuracy:  100.0 %
# Cost:  0.5396329114924285
#
# Effective epoch:  522.0
# Accuracy:  100.0 %
# Cost:  0.5361663589969644
#
# Effective epoch:  523.0
# Accuracy:  100.0 %
# Cost:  0.5326254038151975
#
# Effective epoch:  524.0
# Accuracy:  100.0 %
# Cost:  0.5290095933669472
#
# Effective epoch:  525.0
# Accuracy:  100.0 %
# Cost:  0.5253185759201869
#
# Effective epoch:  526.0
# Accuracy:  100.0 %
# Cost:  0.5215521079441925
#
# Effective epoch:  527.0
# Accuracy:  100.0 %
# Cost:  0.5177100614752091
#
# Effective epoch:  528.0
# Accuracy:  100.0 %
# Cost:  0.5137924314413198
#
# Effective epoch:  529.0
# Accuracy:  100.0 %
# Cost:  0.5097993428881276
#
# Effective epoch:  530.0
# Accuracy:  100.0 %
# Cost:  0.5057310580420369
#
# Effective epoch:  531.0
# Accuracy:  100.0 %
# Cost:  0.501587983143387
#
# Effective epoch:  532.0
# Accuracy:  100.0 %
# Cost:  0.49737067497760445
#
# Effective epoch:  533.0
# Accuracy:  100.0 %
# Cost:  0.4930798470290286
#
# Effective epoch:  534.0
# Accuracy:  100.0 %
# Cost:  0.4887163751792324
#
# Effective epoch:  535.0
# Accuracy:  100.0 %
# Cost:  0.4842813028696792
#
# Effective epoch:  536.0
# Accuracy:  100.0 %
# Cost:  0.4797758456475176
#
# Effective epoch:  537.0
# Accuracy:  100.0 %
# Cost:  0.47520139501338543
#
# Effective epoch:  538.0
#
# Effective epoch:  573.0
# Accuracy:  100.0 %
# Cost:  0.288888155810326
#
# Effective epoch:  574.0
# Accuracy:  100.0 %
# Cost:  0.2839678305130882
#
# Effective epoch:  575.0
# Accuracy:  100.0 %
# Cost:  0.27910463452562273
#
# Effective epoch:  576.0
# Accuracy:  100.0 %
# Cost:  0.27430080806190765
#
# Effective epoch:  577.0
# Accuracy:  100.0 %
# Cost:  0.26955841086320187
#
# Effective epoch:  578.0
# Accuracy:  100.0 %
# Cost:  0.26487932198876546
#
# Effective epoch:  579.0
# Accuracy:  100.0 %
# Cost:  0.26026524062996137
#
# Effective epoch:  580.0
# Accuracy:  100.0 %
# Cost:  0.25571768788217286
#
# Effective epoch:  581.0
# Accuracy:  100.0 %
# Cost:  0.25123800940286833
#
# Effective epoch:  582.0
# Accuracy:  100.0 %
# Cost:  0.246827378879522
#
# Effective epoch:  583.0
# Accuracy:  100.0 %
# Cost:  0.24248680222792585
#
# Effective epoch:  584.0
# Accuracy:  100.0 %
# Cost:  0.2382171224396204
#
# Effective epoch:  585.0
# Accuracy:  100.0 %
# Cost:  0.23401902499663615
#
# Effective epoch:  586.0
# Accuracy:  100.0 %
# Cost:  0.22989304377236297
#
# Effective epoch:  587.0
# Accuracy:  100.0 %
# Cost:  0.22583956733902552
#
# Effective epoch:  588.0
# Accuracy:  100.0 %
# Cost:  0.22185884560480135
#
# Effective epoch:  589.0
# Accuracy:  100.0 %
# Cost:  0.2179509967069485
#
# Effective epoch:  590.0
# Accuracy:  100.0 %
# Cost:  0.21411601409126188
#
# Effective epoch:  591.0
# Accuracy:  100.0 %
# Cost:  0.21035377371262984
#
# Effective epoch:  592.0
# Accuracy:  100.0 %
# Cost:  0.2066640412962826
#
# Effective epoch:  593.0
# Accuracy:  100.0 %
# Cost:  0.20304647960439776
#
# Effective epoch:  594.0
# Accuracy:  100.0 %
# Cost:  0.1995006556579383
#
# Effective epoch:  595.0
# Accuracy:  100.0 %
# Cost:  0.19602604786886701
#
# Effective epoch:  596.0
# Accuracy:  100.0 %
# Cost:  0.19262205304309496
#
# Effective epoch:  597.0
# Accuracy:  100.0 %
# Cost:  0.1892879932196371
#
# Effective epoch:  598.0
# Accuracy:  100.0 %
# Cost:  0.18602312231638227
#
# Effective epoch:  599.0
# Accuracy:  100.0 %
# Cost:  0.1828266325575959
#
# Effective epoch:  600.0
# Accuracy:  100.0 %
# Cost:  0.1796976606627245
#
# Effective epoch:  601.0
# Accuracy:  100.0 %
# Cost:  0.1766352937802302
#
# Effective epoch:  602.0
# Accuracy:  100.0 %
# Cost:  0.17363857515402664
#
# Effective epoch:  603.0
# Accuracy:  100.0 %
# Cost:  0.17070650951361352
#
# Effective epoch:  604.0
# Accuracy:  100.0 %
# Cost:  0.16783806818220176
#
# Effective epoch:  605.0
# Accuracy:  100.0 %
# Cost:  0.16503219389998522
#
# Effective epoch:  606.0
# Accuracy:  100.0 %
# Cost:  0.1622878053622686
#
# Effective epoch:  607.0
# Accuracy:  100.0 %
# Cost:  0.15960380147439346
#
# Effective epoch:  608.0
# Accuracy:  100.0 %
# Cost:  0.15697906532734907
# Effective epoch:  609.0
# Accuracy:  100.0 %
# Cost:  0.15441246789961502
#
# Effective epoch:  610.0
# Accuracy:  100.0 %
# Cost:  0.15190287149218498
#
# Effective epoch:  611.0
# Accuracy:  100.0 %
# Cost:  0.1494491329048783
#
# Effective epoch:  612.0
# Accuracy:  100.0 %
# Cost:  0.14705010636298127
#
# Effective epoch:  613.0
# Accuracy:  100.0 %
# Cost:  0.1447046462039965
#
# Effective epoch:  614.0
# Accuracy:  100.0 %
# Cost:  0.1424116093348287
#
# Effective epoch:  615.0
# Accuracy:  100.0 %
# Cost:  0.14016985747012423
#
# Effective epoch:  616.0
# Accuracy:  100.0 %
# Cost:  0.13797825916272857
#
# Effective epoch:  617.0
# Accuracy:  100.0 %
# Cost:  0.1358356916373405
#
# Effective epoch:  618.0
# Accuracy:  100.0 %
# Cost:  0.13374104243845542
#
# Effective epoch:  619.0
# Accuracy:  100.0 %
# Cost:  0.1316932109036005
#
# Effective epoch:  620.0
# Accuracy:  100.0 %
# Cost:  0.1296911094727003
#
# Effective epoch:  621.0
# Accuracy:  100.0 %
# Cost:  0.12773366484418147
#
# Effective epoch:  622.0
# Accuracy:  100.0 %
# Cost:  0.12581981898813366
#
# Effective epoch:  623.0
# Accuracy:  100.0 %
# Cost:  0.12394853002651604
#
# Effective epoch:  624.0
# Accuracy:  100.0 %
# Cost:  0.12211877299003279
#
# Effective epoch:  625.0
# Accuracy:  100.0 %
# Cost:  0.12032954046090538
#
# Effective epoch:  626.0
# Accuracy:  100.0 %
# Cost:  0.11857984311036485
#
# Effective epoch:  627.0
# Accuracy:  100.0 %
# Cost:  0.11686871013925831
#
# Effective epoch:  628.0
# Accuracy:  100.0 %
# Cost:  0.11519518962973939
#
# Effective epoch:  629.0
# Accuracy:  100.0 %
# Cost:  0.11355834881557943
#
# Effective epoch:  630.0
# Accuracy:  100.0 %
# Cost:  0.11195727427820745
#
# Effective epoch:  631.0
# Accuracy:  100.0 %
# Cost:  0.1103910720751666
#
# Effective epoch:  632.0
# Accuracy:  100.0 %
# Cost:  0.1088588678072579
#
# Effective epoch:  633.0
# Accuracy:  100.0 %
# Cost:  0.10735980663024228
#
# Effective epoch:  634.0
# Accuracy:  100.0 %
# Cost:  0.10589305321657938
#
# Effective epoch:  635.0
# Accuracy:  100.0 %
# Cost:  0.10445779167230712
#
# Effective epoch:  636.0
# Accuracy:  100.0 %
# Cost:  0.10305322541380588
#
# Effective epoch:  637.0
# Accuracy:  100.0 %
# Cost:  0.10167857700884421
#
# Effective epoch:  638.0
# Accuracy:  100.0 %
# Cost:  0.10033308798597909
#
# Effective epoch:  639.0
# Accuracy:  100.0 %
# Cost:  0.09901601861606595
#
# Effective epoch:  640.0
# Accuracy:  100.0 %
# Cost:  0.09772664766934742
#
# Effective epoch:  641.0
# Accuracy:  100.0 %
# Cost:  0.09646427215130382
#
# Effective epoch:  642.0
# Accuracy:  100.0 %
# Cost:  0.09522820702019069
#
# Effective epoch:  643.0
# Accuracy:  100.0 %
# Cost:  0.09401778488894266
#
# Effective epoch:  644.0
# Accuracy:  100.0 %
# Cost:  0.09283235571389363
#
# Effective epoch:  645.0
# Accuracy:  100.0 %
# Cost:  0.09167128647254304
#
# Effective epoch:  646.0
# Accuracy:  100.0 %
# Cost:  0.09053396083240647
#
# Effective epoch:  647.0
# Accuracy:  100.0 %
# Cost:  0.08941977881279213
#
# Effective epoch:  648.0
# Accuracy:  100.0 %
# Cost:  0.08832815644117822
#
# Effective epoch:  649.0
# Accuracy:  100.0 %
# Cost:  0.08725852540570156
#
# Effective epoch:  650.0
# Accuracy:  100.0 %
# Cost:  0.08621033270512078
#
# Effective epoch:  651.0
# Accuracy:  100.0 %
# Cost:  0.08518304029747742
#
# Effective epoch:  652.0
# Accuracy:  100.0 %
# Cost:  0.08417612474855302
#
# Effective epoch:  653.0
# Accuracy:  100.0 %
# Cost:  0.08318907688110141
#
# Effective epoch:  654.0
# Accuracy:  100.0 %
# Cost:  0.0822214014257291
#
# Effective epoch:  655.0
# Accuracy:  100.0 %
# Cost:  0.08127261667419673
#
# Effective epoch:  656.0
# Accuracy:  100.0 %
# Cost:  0.0803422541358229
#
# Effective epoch:  657.0
# Accuracy:  100.0 %
# Cost:  0.07942985819759026
#
# Effective epoch:  658.0
# Accuracy:  100.0 %
# Cost:  0.07853498578847647
#
# Effective epoch:  659.0
# Accuracy:  100.0 %
# Cost:  0.07765720604846334
#
# Effective epoch:  660.0
# Accuracy:  100.0 %
# Cost:  0.07679610000261444
#
# Effective epoch:  661.0
# Accuracy:  100.0 %
# Cost:  0.07595126024055393
#
# Effective epoch:  662.0
# Accuracy:  100.0 %
# Cost:  0.07512229060162652
#
# Effective epoch:  663.0
# Accuracy:  100.0 %
# Cost:  0.07430880586597219
#
# Effective epoch:  664.0
# Accuracy:  100.0 %
# Cost:  0.07351043145170531
#
# Effective epoch:  665.0
# Accuracy:  100.0 %
# Cost:  0.07272680311834825
#
# Effective epoch:  666.0
# Accuracy:  100.0 %
# Cost:  0.07195756667663955
#
# Effective epoch:  667.0
# Accuracy:  100.0 %
# Cost:  0.07120237770479698
#
# Effective epoch:  668.0
# Accuracy:  100.0 %
# Cost:  0.07046090127129595
#
# Effective epoch:  669.0
# Accuracy:  100.0 %
# Cost:  0.06973281166419357
#
# Effective epoch:  670.0
# Accuracy:  100.0 %
# Cost:  0.0690177921270076
#
# Effective epoch:  671.0
# Accuracy:  100.0 %
# Cost:  0.0683155346011401
#
# Effective epoch:  672.0
# Accuracy:  100.0 %
# Cost:  0.06762573947481676
#
# Effective epoch:  673.0
# Accuracy:  100.0 %
# Cost:  0.06694811533849943
#
# Effective epoch:  674.0
# Accuracy:  100.0 %
# Cost:  0.06628237874671096
#
# Effective epoch:  675.0
# Accuracy:  100.0 %
# Cost:  0.06562825398620667
#
# Effective epoch:  676.0
# Accuracy:  100.0 %
# Cost:  0.06498547285040908
#
# Effective epoch:  1493.0
# Accuracy:  100.0 %
# Cost:  0.0067826678633593615
#
# Effective epoch:  1494.0
# Accuracy:  100.0 %
# Cost:  0.006775498276276007
#
# Effective epoch:  1495.0
# Accuracy:  100.0 %
# Cost:  0.006768344400449823
#
# Effective epoch:  1496.0
# Accuracy:  100.0 %
# Cost:  0.006761206183627163
#
# Effective epoch:  1497.0
# Accuracy:  100.0 %
# Cost:  0.006754083573786478
#
# Effective epoch:  1498.0
# Accuracy:  100.0 %
# Cost:  0.006746976519137682
#
# Effective epoch:  1499.0
# Accuracy:  100.0 %
# Cost:  0.0067398849681202825
#
# Effective epoch:  1500.0
# Accuracy:  100.0 %
# Cost:  0.006732808869402419
#
# Time Taken:  1.7944087982177734  seconds
# Accuracy:  100.0
# Effective epoch:  1.0
# Cost:  3.1317798715079705
#
# Effective epoch:  2.0
# Cost:  0.27798002301710184
#
# Effective epoch:  3.0
# Cost:  0.27749643831635085
#
# Effective epoch:  4.0
# Cost:  0.27757427398386164
#
# Effective epoch:  5.0
# Cost:  0.27755588262349734
#
# Time Taken:  2.8896572589874268  seconds
# Effective epoch:  1.0
# Cost:  396.4776043170161
#
# Effective epoch:  2.0
# Cost:  0.4741730292867235
#
# Effective epoch:  3.0
# Cost:  0.07054090319896954
#
# Effective epoch:  4.0
# Cost:  0.06008800353331986
#
# Effective epoch:  5.0
# Cost:  0.05624840916375834
#
# Effective epoch:  6.0
# Cost:  0.053030742038644184
#
# Effective epoch:  7.0
# Cost:  0.050343609282548184
#
# Effective epoch:  8.0
# Cost:  0.04817901306142268
#
# Effective epoch:  9.0
# Cost:  0.046487096068959316
#
# Effective epoch:  10.0
# Cost:  0.04475680423299684
#
# Time Taken:  5.4492411613464355  seconds
# Text(0.5, 1.0, 'Regression with 20 hidden Units')

# %%
NN2 = DeepNN([1,20,1], activations=['tanh','identity'],epsilon=2)
w = NN2.learn(epochs=20000, learning_rate=0.001, X=X, y=t, cost_func='least_squares', metrics_at=2000, optimizer='rmsprop',batch_size=5)
plt.title('Regression with 20 Hidden Units Cost Function')

# plot the model
x_mesh = np.linspace(np.min(X)-0.25,np.max(X)+0.25,500).reshape(500,1)
y = NN2.think(x_mesh)

plt.figure()
plt.plot(x_mesh, y, 'r')
plt.scatter(X,t)
plt.title('Regression with 20 hidden Units')
# Out:
# Effective epoch:  1.0
# Cost:  412.41541956505864
#
# Effective epoch:  2.0
# Cost:  0.2534659801685347
#
# Effective epoch:  3.0
# Cost:  0.06232005858535044
#
# Effective epoch:  4.0
# Cost:  0.05411592009875381
#
# Effective epoch:  5.0
# Cost:  0.051007405286132075
#
# Effective epoch:  6.0
# Cost:  0.04977140206060773
#
# Effective epoch:  7.0
# Cost:  0.04931079731525693
#
# Effective epoch:  8.0
# Cost:  0.049153020790150236
#
# Effective epoch:  9.0
# Cost:  0.04899747760518107
#
# Effective epoch:  10.0
# Cost:  0.04873676881697905
#
# Time Taken:  11.831694841384888  seconds
# Text(0.5, 1.0, 'Regression with 20 hidden Units')
